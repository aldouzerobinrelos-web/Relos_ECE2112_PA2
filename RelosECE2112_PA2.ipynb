# %%
import numpy as np

# %% [markdown]
# # **A. REPRODUCIBLE NORMALIZATION**

# %%
np.random.seed(2112)
X = np.random.randint(10, 101, size=(5, 5))
x = X.mean()
σ = X.std()
X_normalized = (X - x)/σ
x_normalized = X_normalized.mean()
σ_normalized = X_normalized.std()

# %% [markdown]
# **X**

# %%
display(X)
# Out:
# array([[48, 11, 15, 67, 21],
#        [11, 41, 13, 66, 24],
#        [71, 79, 53, 67, 70],
#        [77, 35, 91, 19, 96],
#        [35, 54, 37, 41, 17]])

# %% [markdown]
# **X_normalized**

# %%
display(X_normalized)
# Out:
# array([[ 0.06340841, -1.36714726, -1.2124926 ,  0.79801809, -0.98051059],
#        [-1.36714726, -0.20723725, -1.28981993,  0.75935442, -0.86451959],
#        [ 0.95267275,  1.26198209,  0.25672675,  0.79801809,  0.91400909],
#        [ 1.18465476, -0.43921926,  1.72594609, -1.05783793,  1.91926443],
#        [-0.43921926,  0.29539042, -0.36189192, -0.20723725, -1.13516526]])

# %% [markdown]
# **x_normalized**

# %%
display(x_normalized)
# Out:
# np.float64(0.0)

# %% [markdown]
# **σ_normalized**

# %%
display(σ_normalized)
# Out:
# np.float64(0.9999999999999999)

# %%
np.save("X_normalized.npy",X_normalized)

# %% [markdown]
# # **B. CUBES DIVISIBLE BY 4 PROBLEM**

# %%
c = (np.arange(1, 101)**3).reshape(10, 10)
div4 = c%4 == 0
div_by_4 = c[div4].reshape(5,10)

# %% [markdown]
# **Shape of C**

# %%
display(c.shape)
# Out:
# (10, 10)

# %% [markdown]
# **div_by_4 array**

# %%
display(div_by_4)
# Out:
# array([[      8,      64,     216,     512,    1000,    1728,    2744,
#            4096,    5832,    8000],
#        [  10648,   13824,   17576,   21952,   27000,   32768,   39304,
#           46656,   54872,   64000],
#        [  74088,   85184,   97336,  110592,  125000,  140608,  157464,
#          175616,  195112,  216000],
#        [ 238328,  262144,  287496,  314432,  343000,  373248,  405224,
#          438976,  474552,  512000],
#        [ 551368,  592704,  636056,  681472,  729000,  778688,  830584,
#          884736,  941192, 1000000]])

# %% [markdown]
# **Number of Elements**

# %%
display(div_by_4.size)
# Out:
# 50

# %%
np.save("div_by_4.npy",div_by_4)

# %% [markdown]
# # **C. ABOVE-MEAN SQUARES PROBLEM**

# %%
S = (np.arange(1, 37)**2).reshape(6,6)
S_mean = np.mean(S)
above_mean = S[S > S_mean].reshape(3,5)

# %% [markdown]
# **Array of S**

# %%
display(S)
# Out:
# array([[   1,    4,    9,   16,   25,   36],
#        [  49,   64,   81,  100,  121,  144],
#        [ 169,  196,  225,  256,  289,  324],
#        [ 361,  400,  441,  484,  529,  576],
#        [ 625,  676,  729,  784,  841,  900],
#        [ 961, 1024, 1089, 1156, 1225, 1296]])

# %% [markdown]
# **Mean of S**

# %%
display(S_mean)
# Out:
# np.float64(450.1666666666667)

# %% [markdown]
# **above_mean array**

# %%
display(above_mean)
# Out:
# array([[ 484,  529,  576,  625,  676],
#        [ 729,  784,  841,  900,  961],
#        [1024, 1089, 1156, 1225, 1296]])

# %%
np.save("above_mean.npy",above_mean)
